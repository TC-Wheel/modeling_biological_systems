# %% [markdown]
# # Homework 3

# %% [markdown]
# BIOCHEM 570

# %% [markdown]
# Name

# %% [markdown]
# ## 1 - Linear Algebra

# %% [markdown]
# #### MMSB B.2.1 -- pg 305

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### MMSB B.2.3 -- pg 307

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2 - Kinetics Part 2

# %% [markdown]
# #### MMSB 3.7.10  -- pg 72

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# b seems to have a typo... There's no question for b?

# %% [markdown]
# #### MMSB 3.7.12 -- pg 74

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3 - Analysis of Dynamic Mathematical Models

# %% [markdown]
# #### MMSB 4.8.3 -- pg 106

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4 - Allee Effect

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
