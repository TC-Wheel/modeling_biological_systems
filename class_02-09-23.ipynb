# %% [markdown]
# HW 1 is due.
#
# Look at the videos with plugging in ODE simulations in Python. (Super useful.)
# - Rapid equilibrium approximation (assumes fast reactions dominate)
# - Quasi-steady-state approximation (certain species are not changing...?)

# %%
from matplotlib import pyplot as plt
import numpy as np

def dirv(a):
    k = 1
    return -k*a


t = [0]
a = [2]
h = 0.1
output = []

count = 0

#run a loop of euler's method
for i in range(100):
    t.append(t[i]+h)
    a.append(a[i]+ h * dirv(a[i]))

plt.plot(t, a)


#you can use linspace as well, something like this?
# time = np.linspace(0, 2, 100)
# h = np.diff(time)[0]

#analytical solution (I didn't do this. -- because I'm not exactly sure how. But apparently it's really easy..?)

#compare the analytical solution

#plot
