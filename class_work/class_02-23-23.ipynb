# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
x = np.linspace(0,2,50)

s1_nullcline = 1/(1+x) #replace with equation
s2_nullcline = 1+x #replace with equation

plt.plot(x, s1_nullcline, s2_nullcline)
plt.ylim(0,2)
plt.xlim(0,2)
# Out:
# (0.0, 2.0)

# %%
n = np.linspace(0,10,50)

s1_nullcline = (1+(3/2)) #replace with equation
s2_nullcline = 1+x #replace with equation

plt.plot(x, s1_nullcline, s2_nullcline)
